# %% [markdown]
# # Get Food Safety Authority Data

# %%
import pandas as pd
from urllib.request import urlopen
import xml.etree.ElementTree as ET
from collections import OrderedDict
from io import StringIO

def download_foodsafety_data_and_convert_to_csv(xml_id='FHRS776en-GB.xml', out_fpath='food_safety.csv'):
    """
    Downloads food safety data given the local authority id which can be 
    found at http://ratings.food.gov.uk/open-data/en-GB 
    """
    url = 'http://ratings.food.gov.uk/OpenDataFiles/{}'.format(xml_id)
    response = urlopen(url)
    content = StringIO(response.read().decode())

    def get_info_from_xml():
        etree = ET.parse(content)
        root = etree.getroot()
        for enstab in root.iter('EstablishmentDetail'):
            d = OrderedDict()
            for item in enstab:
                if item.tag == 'Geocode':
                    for ll_info in item:
                        d[ll_info.tag] = float(ll_info.text)
                else:
                    d[item.tag] = item.text
            yield d

    df = pd.DataFrame(list(get_info_from_xml()))
    df.to_csv(out_fpath, index=None)

# %%
download_foodsafety_data_and_convert_to_csv(xml_id='FHRS776en-GB.xml', out_fpath='food_safety_Glasgow.csv')

# %% [markdown]
# # Get Yelp Data

# %% [markdown]
# To get a Yelp API KEY follow [these info](https://www.yelp.com/developers/documentation/v3/authentication).
# Then create a file called api_key.py with *YELP_API_KEY=<your yelp api key\>*

# %%
from api_key import YELP_API_KEY

# %%
import pandas as pd
import numpy as np
import requests
from urllib.parse import quote
import json

class Client():
    endpoint = 'https://api.yelp.com/v3/businesses/search?'
    valid_seach_keys = ['term','location','latitude','longitude','radius','categories','locale','limit','offset','sort_by','price','open_now','open_at','attributes']

    def __init__(self, api_key):
        self.api_key = api_key
    
    def request(self, endpoint):
        #print(f'GET requesting: {endpoint}')
        headers = {"Authorization":f"Bearer {self.api_key}"}
        r = requests.get(endpoint, headers=headers)
        return r
        
    def search_businesses(self, **kwargs):
        verbose = kwargs.pop('verbose', False)
        for k in kwargs.keys():
            assert k in self.valid_seach_keys
        search_values = [f'{k}={quote(str(v))}' for k,v in kwargs.items()]
        url = self.endpoint + '&'.join(search_values)
        if verbose: print('Sending request:', url)
        r = self.request(url)
        return r
    
def save_to_json(obj, fpath='yelp.json'):
    with open(fpath, 'w') as f:
        json.dump(obj, f)

def load_from_json(fpath='yelp.json'):
    with open(fpath, 'r') as f:
        content = json.load(f)
    return content


class SearchGrid:
    cos30 = np.cos(np.deg2rad(30))
    def __init__(self, ll_coord, ur_coord, step):
        self.minx, self.miny = ll_coord
        self.maxx, self.maxy = ur_coord
        self.step = step
        self.radius = self.step / 2 / self.cos30
        self.margin = self.step - self.radius
        
    def __len__(self):
        counter = 0
        with_x_offset = True
        y_offset = np.sqrt(np.square(self.radius)-np.square(self.step/2))
        for y in np.arange(self.miny+y_offset, self.maxy+self.step/2, self.step*self.cos30):
            with_x_offset = not with_x_offset
            offset = int(with_x_offset) * self.step/2
            for x in np.arange(self.minx+offset, self.maxx+self.step/2, self.step):
                counter += 1
        return counter
        
    def __iter__(self):
        with_x_offset = True
        y_offset = np.sqrt(np.square(self.radius)-np.square(self.step/2))
        for y in np.arange(self.miny+y_offset, self.maxy+self.step/2, self.step*self.cos30):
            with_x_offset = not with_x_offset
            offset = int(with_x_offset) * self.step/2
            for x in np.arange(self.minx+offset, self.maxx+self.step/2, self.step):
                yield x, y, self.radius

# %%
sg = SearchGrid(ll_coord=ll_coord, ur_coord=ur_coord, step=0.02)
len(sg)
# Out:
# 162

# %%
# minx, miny = (0, 0)
# maxx, maxy = (10, 10)
# sg = SearchGrid(ll_coord=(minx, miny), ur_coord=(maxx, maxy), step=2)

# import matplotlib.pyplot as plt
# %matplotlib inline

# fig, ax = plt.subplots(1,1)
# for x, y, r in sg: 
#     xs = []
#     ys = []
#     for a in np.arange(0, 2*np.pi+0.1, 0.3):
#         xs.append(x+r*np.cos(a))
#         ys.append(y+r*np.sin(a))
#     ax.plot(xs, ys)

# ax.plot([minx,maxx, maxx, minx, minx],[miny, miny, maxy, maxy, miny], 'r--', lw=3)
# ax.grid(True)
# fig.set_size_inches(20,20)

# %%
c = Client(api_key=YELP_API_KEY)

# %%
def approx_radius_to_meters(r, latitude):
    """Converting (roughly) a change in degrees lat/long to meters"""
    r_lat = 110574 * r
    r_lon = 111320 * r * np.cos(np.deg2rad(latitude))
    return max(r_lat, r_lon)

approx_radius_to_meters(r=0.02, latitude=55.863937)
# Out:
# 2211.48

# %%
# latitude, longitude = 55.863937, -4.270185  # M8 bridge
# radius = 5000

CATEGORIES = 'restaurants'
LIMIT = 50  # max=50
MAX_SIZE = 1000  # before yelp API complains

ll_coord = 55.76308604, -4.385425
ur_coord = 55.926417, -4.093184
step = 0.02

all_businesses = []
sg = SearchGrid(ll_coord=ll_coord, ur_coord=ur_coord, step=step)
len_sg = len(sg)
for i, (lat, lon, radius) in enumerate(sg):
    radius_meters = approx_radius_to_meters(radius, lat)
    
    print(f"\rCentre ({lat:3f}, {lon:.3f}), radius {radius_meters:.1f}m ({i+1}/{len_sg})")
    
    offset = 0
    last_search_results = LIMIT
    while last_search_results >= LIMIT and offset < MAX_SIZE:
        r = c.search_businesses(
            latitude=lat, 
            longitude=lon, 
            radius=int(radius_meters*1.05), 
            categories=CATEGORIES, 
            offset=offset, 
            limit=LIMIT,
        )
        if 'error' in r.json():
            print("Error!!")
            print(r.json())
            break

        found_businesses = r.json()['businesses']
        last_search_results = len(found_businesses)
        offset += last_search_results

        all_businesses.extend(found_businesses)
        print(f'added: {last_search_results}, curr len={len(all_businesses)}')

save_to_json(obj=all_businesses, fpath='yelp.json')
# Out:
# Centre (55.763086, -4.380), radius 1276.8m (1/162)
# added: 0, curr len=0
# Centre (55.783086, -4.380), radius 1276.8m (2/162)
# added: 5, curr len=5
# Centre (55.803086, -4.380), radius 1276.8m (3/162)
# added: 5, curr len=10
# Centre (55.823086, -4.380), radius 1276.8m (4/162)
# added: 3, curr len=13
# Centre (55.843086, -4.380), radius 1276.8m (5/162)
# added: 1, curr len=14
# Centre (55.863086, -4.380), radius 1276.8m (6/162)
# added: 26, curr len=40
# Centre (55.883086, -4.380), radius 1276.8m (7/162)
# added: 28, curr len=68
# Centre (55.903086, -4.380), radius 1276.8m (8/162)
# added: 5, curr len=73
# Centre (55.923086, -4.380), radius 1276.8m (9/162)
# added: 3, curr len=76
# Centre (55.773086, -4.362), radius 1276.8m (10/162)
# added: 1, curr len=77
# Centre (55.793086, -4.362), radius 1276.8m (11/162)
# added: 3, curr len=80
# Centre (55.813086, -4.362), radius 1276.8m (12/162)
# added: 5, curr len=85
# Centre (55.833086, -4.362), radius 1276.8m (13/162)
# added: 9, curr len=94
# Centre (55.853086, -4.362), radius 1276.8m (14/162)
# added: 11, curr len=105
# Centre (55.873086, -4.362), radius 1276.8m (15/162)
# added: 35, curr len=140
# Centre (55.893086, -4.362), radius 1276.8m (16/162)
# added: 32, curr len=172
# Centre (55.913086, -4.362), radius 1276.8m (17/162)
# added: 5, curr len=177
# Centre (55.933086, -4.362), radius 1276.8m (18/162)
# added: 2, curr len=179
# Centre (55.763086, -4.345), radius 1276.8m (19/162)
# added: 8, curr len=187
# Centre (55.783086, -4.345), radius 1276.8m (20/162)
# added: 9, curr len=196
# Centre (55.803086, -4.345), radius 1276.8m (21/162)
# added: 25, curr len=221
# Centre (55.823086, -4.345), radius 1276.8m (22/162)
# added: 23, curr len=244
# Centre (55.843086, -4.345), radius 1276.8m (23/162)
# added: 22, curr len=266
# Centre (55.863086, -4.345), radius 1276.8m (24/162)
# added: 21, curr len=287
# Centre (55.883086, -4.345), radius 1276.8m (25/162)
# added: 14, curr len=301
# Centre (55.903086, -4.345), radius 1276.8m (26/162)
# added: 9, curr len=310
# Centre (55.923086, -4.345), radius 1276.8m (27/162)
# added: 9, curr len=319
# Centre (55.773086, -4.328), radius 1276.8m (28/162)
# added: 12, curr len=331
# Centre (55.793086, -4.328), radius 1276.8m (29/162)
# added: 15, curr len=346
# Centre (55.813086, -4.328), radius 1276.8m (30/162)
# added: 4, curr len=350
# Centre (55.833086, -4.328), radius 1276.8m (31/162)
# added: 10, curr len=360
# Centre (55.853086, -4.328), radius 1276.8m (32/162)
# added: 24, curr len=384
# Centre (55.873086, -4.328), radius 1276.8m (33/162)
# added: 40, curr len=424
# Centre (55.893086, -4.328), radius 1276.8m (34/162)
# added: 25, curr len=449
# Centre (55.913086, -4.328), radius 1276.8m (35/162)
# added: 16, curr len=465
# Centre (55.933086, -4.328), radius 1276.8m (36/162)
# added: 20, curr len=485
# Centre (55.763086, -4.310), radius 1276.8m (37/162)
# added: 4, curr len=489
# Centre (55.783086, -4.310), radius 1276.8m (38/162)
# added: 8, curr len=497
# Centre (55.803086, -4.310), radius 1276.8m (39/162)
# added: 8, curr len=505
# Centre (55.823086, -4.310), radius 1276.8m (40/162)
# added: 5, curr len=510
# Centre (55.843086, -4.310), radius 1276.8m (41/162)
# added: 19, curr len=529
# Centre (55.863086, -4.310), radius 1276.8m (42/162)
# added: 50, curr len=579
# added: 50, curr len=629
# added: 3, curr len=632
# Centre (55.883086, -4.310), radius 1276.8m (43/162)
# added: 50, curr len=682
# added: 48, curr len=730
# Centre (55.903086, -4.310), radius 1276.8m (44/162)
# added: 14, curr len=744
# Centre (55.923086, -4.310), radius 1276.8m (45/162)
# added: 16, curr len=760
# Centre (55.773086, -4.293), radius 1276.8m (46/162)
# added: 1, curr len=761
# Centre (55.793086, -4.293), radius 1276.8m (47/162)
# added: 25, curr len=786
# Centre (55.813086, -4.293), radius 1276.8m (48/162)
# added: 50, curr len=836
# added: 5, curr len=841
# Centre (55.833086, -4.293), radius 1276.8m (49/162)
# added: 50, curr len=891
# added: 2, curr len=893
# Centre (55.853086, -4.293), radius 1276.8m (50/162)
# added: 50, curr len=943
# added: 50, curr len=993
# added: 50, curr len=1043
# added: 11, curr len=1054
# Centre (55.873086, -4.293), radius 1276.8m (51/162)
# added: 50, curr len=1104
# added: 50, curr len=1154
# added: 50, curr len=1204
# added: 50, curr len=1254
# added: 15, curr len=1269
# Centre (55.893086, -4.293), radius 1276.8m (52/162)
# added: 50, curr len=1319
# added: 50, curr len=1369
# added: 3, curr len=1372
# Centre (55.913086, -4.293), radius 1276.8m (53/162)
# added: 1, curr len=1373
# Centre (55.933086, -4.293), radius 1276.8m (54/162)
# added: 0, curr len=1373
# Centre (55.763086, -4.276), radius 1276.8m (55/162)
# added: 0, curr len=1373
# Centre (55.783086, -4.276), radius 1276.8m (56/162)
# added: 17, curr len=1390
# Centre (55.803086, -4.276), radius 1276.8m (57/162)
# added: 29, curr len=1419
# Centre (55.823086, -4.276), radius 1276.8m (58/162)
# added: 50, curr len=1469
# added: 50, curr len=1519
# added: 14, curr len=1533
# Centre (55.843086, -4.276), radius 1276.8m (59/162)
# added: 50, curr len=1583
# added: 50, curr len=1633
# added: 50, curr len=1683
# added: 10, curr len=1693
# Centre (55.863086, -4.276), radius 1276.8m (60/162)
# added: 50, curr len=1743
# added: 50, curr len=1793
# added: 50, curr len=1843
# added: 50, curr len=1893
# added: 44, curr len=1937
# Centre (55.883086, -4.276), radius 1276.8m (61/162)
# added: 50, curr len=1987
# added: 50, curr len=2037
# added: 50, curr len=2087
# added: 50, curr len=2137
# added: 8, curr len=2145
# Centre (55.903086, -4.276), radius 1276.8m (62/162)
# added: 5, curr len=2150
# Centre (55.923086, -4.276), radius 1276.8m (63/162)
# added: 0, curr len=2150
# Centre (55.773086, -4.258), radius 1276.8m (64/162)
# added: 1, curr len=2151
# Centre (55.793086, -4.258), radius 1276.8m (65/162)
# added: 9, curr len=2160
# Centre (55.813086, -4.258), radius 1276.8m (66/162)
# added: 50, curr len=2210
# added: 1, curr len=2211
# Centre (55.833086, -4.258), radius 1276.8m (67/162)
# added: 50, curr len=2261
# added: 37, curr len=2298
# Centre (55.853086, -4.258), radius 1276.8m (68/162)
# added: 50, curr len=2348
# added: 50, curr len=2398
# added: 50, curr len=2448
# added: 50, curr len=2498
# added: 50, curr len=2548
# added: 50, curr len=2598
# added: 50, curr len=2648
# added: 50, curr len=2698
# added: 50, curr len=2748
# added: 6, curr len=2754
# Centre (55.873086, -4.258), radius 1276.8m (69/162)
# added: 50, curr len=2804
# added: 50, curr len=2854
# added: 50, curr len=2904
# added: 50, curr len=2954
# added: 50, curr len=3004
# added: 50, curr len=3054
# added: 50, curr len=3104
# added: 50, curr len=3154
# added: 28, curr len=3182
# Centre (55.893086, -4.258), radius 1276.8m (70/162)
# added: 14, curr len=3196
# Centre (55.913086, -4.258), radius 1276.8m (71/162)
# added: 1, curr len=3197
# Centre (55.933086, -4.258), radius 1276.8m (72/162)
# added: 0, curr len=3197
# Centre (55.763086, -4.241), radius 1276.8m (73/162)
# added: 0, curr len=3197
# Centre (55.783086, -4.241), radius 1276.8m (74/162)
# added: 2, curr len=3199
# Centre (55.803086, -4.241), radius 1276.8m (75/162)
# added: 10, curr len=3209
# Centre (55.823086, -4.241), radius 1276.8m (76/162)
# added: 10, curr len=3219
# Centre (55.843086, -4.241), radius 1276.8m (77/162)
# added: 50, curr len=3269
# added: 50, curr len=3319
# added: 50, curr len=3369
# added: 36, curr len=3405
# Centre (55.863086, -4.241), radius 1276.8m (78/162)
# added: 50, curr len=3455
# added: 50, curr len=3505
# added: 50, curr len=3555
# added: 41, curr len=3596
# Centre (55.883086, -4.241), radius 1276.8m (79/162)
# added: 42, curr len=3638
# Centre (55.903086, -4.241), radius 1276.8m (80/162)
# added: 9, curr len=3647
# Centre (55.923086, -4.241), radius 1276.8m (81/162)
# added: 0, curr len=3647
# Centre (55.773086, -4.224), radius 1276.8m (82/162)
# added: 5, curr len=3652
# Centre (55.793086, -4.224), radius 1276.8m (83/162)
# added: 4, curr len=3656
# Centre (55.813086, -4.224), radius 1276.8m (84/162)
# added: 20, curr len=3676
# Centre (55.833086, -4.224), radius 1276.8m (85/162)
# added: 25, curr len=3701
# Centre (55.853086, -4.224), radius 1276.8m (86/162)
# added: 42, curr len=3743
# Centre (55.873086, -4.224), radius 1276.8m (87/162)
# added: 40, curr len=3783
# Centre (55.893086, -4.224), radius 1276.8m (88/162)
# added: 17, curr len=3800
# Centre (55.913086, -4.224), radius 1276.8m (89/162)
# added: 13, curr len=3813
# Centre (55.933086, -4.224), radius 1276.8m (90/162)
# added: 2, curr len=3815
# Centre (55.763086, -4.206), radius 1276.8m (91/162)
# added: 8, curr len=3823
# Centre (55.783086, -4.206), radius 1276.8m (92/162)
# added: 4, curr len=3827
# Centre (55.803086, -4.206), radius 1276.8m (93/162)
# added: 5, curr len=3832
# Centre (55.823086, -4.206), radius 1276.8m (94/162)
# added: 21, curr len=3853
# Centre (55.843086, -4.206), radius 1276.8m (95/162)
# added: 46, curr len=3899
# Centre (55.863086, -4.206), radius 1276.8m (96/162)
# added: 34, curr len=3933
# Centre (55.883086, -4.206), radius 1276.8m (97/162)
# added: 19, curr len=3952
# Centre (55.903086, -4.206), radius 1276.8m (98/162)
# added: 7, curr len=3959
# Centre (55.923086, -4.206), radius 1276.8m (99/162)
# added: 1, curr len=3960
# Centre (55.773086, -4.189), radius 1276.8m (100/162)
# added: 9, curr len=3969
# Centre (55.793086, -4.189), radius 1276.8m (101/162)
# added: 3, curr len=3972
# Centre (55.813086, -4.189), radius 1276.8m (102/162)
# added: 9, curr len=3981
# Centre (55.833086, -4.189), radius 1276.8m (103/162)
# added: 12, curr len=3993
# Centre (55.853086, -4.189), radius 1276.8m (104/162)
# added: 9, curr len=4002
# Centre (55.873086, -4.189), radius 1276.8m (105/162)
# added: 9, curr len=4011
# Centre (55.893086, -4.189), radius 1276.8m (106/162)
# added: 1, curr len=4012
# Centre (55.913086, -4.189), radius 1276.8m (107/162)
# added: 1, curr len=4013
# Centre (55.933086, -4.189), radius 1276.8m (108/162)
# added: 1, curr len=4014
# Centre (55.763086, -4.172), radius 1276.8m (109/162)
# added: 40, curr len=4054
# Centre (55.783086, -4.172), radius 1276.8m (110/162)
# added: 21, curr len=4075
# Centre (55.803086, -4.172), radius 1276.8m (111/162)
# added: 15, curr len=4090
# Centre (55.823086, -4.172), radius 1276.8m (112/162)
# added: 17, curr len=4107
# Centre (55.843086, -4.172), radius 1276.8m (113/162)
# added: 15, curr len=4122
# Centre (55.863086, -4.172), radius 1276.8m (114/162)
# added: 16, curr len=4138
# Centre (55.883086, -4.172), radius 1276.8m (115/162)
# added: 4, curr len=4142
# Centre (55.903086, -4.172), radius 1276.8m (116/162)
# added: 3, curr len=4145
# Centre (55.923086, -4.172), radius 1276.8m (117/162)
# added: 0, curr len=4145
# Centre (55.773086, -4.154), radius 1276.8m (118/162)
# added: 7, curr len=4152
# Centre (55.793086, -4.154), radius 1276.8m (119/162)
# added: 4, curr len=4156
# Centre (55.813086, -4.154), radius 1276.8m (120/162)
# added: 4, curr len=4160
# Centre (55.833086, -4.154), radius 1276.8m (121/162)
# added: 12, curr len=4172
# Centre (55.853086, -4.154), radius 1276.8m (122/162)
# added: 9, curr len=4181
# Centre (55.873086, -4.154), radius 1276.8m (123/162)
# added: 11, curr len=4192
# Centre (55.893086, -4.154), radius 1276.8m (124/162)
# added: 4, curr len=4196
# Centre (55.913086, -4.154), radius 1276.8m (125/162)
# added: 6, curr len=4202
# Centre (55.933086, -4.154), radius 1276.8m (126/162)
# added: 13, curr len=4215
# Centre (55.763086, -4.137), radius 1276.8m (127/162)
# added: 0, curr len=4215
# Centre (55.783086, -4.137), radius 1276.8m (128/162)
# added: 0, curr len=4215
# Centre (55.803086, -4.137), radius 1276.8m (129/162)
# added: 2, curr len=4217
# Centre (55.823086, -4.137), radius 1276.8m (130/162)
# added: 2, curr len=4219
# Centre (55.843086, -4.137), radius 1276.8m (131/162)
# added: 5, curr len=4224
# Centre (55.863086, -4.137), radius 1276.8m (132/162)
# added: 16, curr len=4240
# Centre (55.883086, -4.137), radius 1276.8m (133/162)
# added: 11, curr len=4251
# Centre (55.903086, -4.137), radius 1276.8m (134/162)
# added: 0, curr len=4251
# Centre (55.923086, -4.137), radius 1276.8m (135/162)
# added: 1, curr len=4252
# Centre (55.773086, -4.120), radius 1276.8m (136/162)
# added: 0, curr len=4252
# Centre (55.793086, -4.120), radius 1276.8m (137/162)
# added: 0, curr len=4252
# Centre (55.813086, -4.120), radius 1276.8m (138/162)
# added: 0, curr len=4252
# Centre (55.833086, -4.120), radius 1276.8m (139/162)
# added: 9, curr len=4261
# Centre (55.853086, -4.120), radius 1276.8m (140/162)
# added: 15, curr len=4276
# Centre (55.873086, -4.120), radius 1276.8m (141/162)
# added: 7, curr len=4283
# Centre (55.893086, -4.120), radius 1276.8m (142/162)
# added: 3, curr len=4286
# Centre (55.913086, -4.120), radius 1276.8m (143/162)
# added: 3, curr len=4289
# Centre (55.933086, -4.120), radius 1276.8m (144/162)
# added: 1, curr len=4290
# Centre (55.763086, -4.103), radius 1276.8m (145/162)
# added: 1, curr len=4291
# Centre (55.783086, -4.103), radius 1276.8m (146/162)
# added: 9, curr len=4300
# Centre (55.803086, -4.103), radius 1276.8m (147/162)
# added: 8, curr len=4308
# Centre (55.823086, -4.103), radius 1276.8m (148/162)
# added: 2, curr len=4310
# Centre (55.843086, -4.103), radius 1276.8m (149/162)
# added: 12, curr len=4322
# Centre (55.863086, -4.103), radius 1276.8m (150/162)
# added: 10, curr len=4332
# Centre (55.883086, -4.103), radius 1276.8m (151/162)
# added: 6, curr len=4338
# Centre (55.903086, -4.103), radius 1276.8m (152/162)
# added: 7, curr len=4345
# Centre (55.923086, -4.103), radius 1276.8m (153/162)
# added: 1, curr len=4346
# Centre (55.773086, -4.085), radius 1276.8m (154/162)
# added: 9, curr len=4355
# Centre (55.793086, -4.085), radius 1276.8m (155/162)
# added: 9, curr len=4364
# Centre (55.813086, -4.085), radius 1276.8m (156/162)
# added: 13, curr len=4377
# Centre (55.833086, -4.085), radius 1276.8m (157/162)
# added: 8, curr len=4385
# Centre (55.853086, -4.085), radius 1276.8m (158/162)
# added: 0, curr len=4385
# Centre (55.873086, -4.085), radius 1276.8m (159/162)
# added: 4, curr len=4389
# Centre (55.893086, -4.085), radius 1276.8m (160/162)
# added: 6, curr len=4395
# Centre (55.913086, -4.085), radius 1276.8m (161/162)
# added: 3, curr len=4398
# Centre (55.933086, -4.085), radius 1276.8m (162/162)
# added: 1, curr len=4399

# %% [markdown]
# # Convert json to table

# %%
def convert_item_to_record(b):
    EXCLUDE = ['display_address']
    record = {}
    for k,v in b.items():
        if k in EXCLUDE: continue
        if isinstance(v, (int, float, bool, str)):
            record[k] = v
        elif isinstance(v, dict):
            sub_record = convert_item_to_record(v)
            record.update(sub_record)
    return record

# %%
all_businesses = load_from_json(fpath='yelp.json')

# %%
records = [convert_item_to_record(b) for b in all_businesses]
df = pd.DataFrame(records)

ordered_col = [
    'name', 'rating', 'review_count',  'price',
    'latitude', 'longitude', 'zip_code', 
    'id', 'alias',
    'address1', 'address2', 'address3',  'city', 'state', 'country',
    'display_phone', 'image_url', 'phone', 'url'
]

# %%
df.drop_duplicates(subset='id')[ordered_col].to_csv('yelp.csv', index=None)

# %% [markdown]
# ## Matching information

# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %%
df_fsa = pd.read_csv('food_safety_Glasgow.csv')
df_yelp_full = pd.read_csv('yelp.csv')

# %%
df_yelp = df_yelp_full[['name', 'latitude', 'longitude', 'zip_code', 'id', 'address1']].copy()
df_fsa = df_fsa[['FHRSID', 'BusinessName', 'AddressLine2', 'PostCode', 'Longitude', 'Latitude']].copy()

df_yelp = df_yelp[pd.notnull(df_yelp.latitude) & pd.notnull(df_yelp['name'])]
df_fsa = df_fsa[pd.notnull(df_fsa.Latitude) & pd.notnull(df_fsa['BusinessName'])]

# %%
def get_distance_score(lat, lon, lat_ref, lon_ref):
    lat_diff = lat - lat_ref
    lon_diff = lon - lon_ref
    pseudo_dist = np.hypot(lat_diff, lon_diff)
    return np.exp(-pseudo_dist*100)

@np.vectorize
def get_str_compare_score(addr, addr_ref):
    score = SequenceMatcher(None, addr, addr_ref).ratio()
    return score

# %%
DIST_SCORE_THREASHOLD = 0.9
NAME_SCORE_THREASHOLD = 0.5

MATCHES = {}
def find_matches(df):
    for i_counter, (idx, item) in enumerate(df.iterrows()):
        search_df = df_fsa.copy()

        # filter by distance
        # ==================
        score_dist = get_distance_score(
            lat=search_df.Latitude, lon=search_df.Longitude, 
            lat_ref=item.latitude, lon_ref=item.longitude
        )
        search_df = search_df[score_dist >= DIST_SCORE_THREASHOLD]
        if search_df.empty: continue

        # score by name
        # =============
        search_df['scores'] = get_str_compare_score(addr=search_df.BusinessName, addr_ref=item['name'])
        search_df = search_df[search_df['scores'] >= NAME_SCORE_THREASHOLD]
        MATCHES[item['id']] = search_df[['FHRSID','scores']].set_index('FHRSID')['scores'].to_dict()

        # get best match
        # ==============
        if search_df.empty:
            idx_best_match = score_best_match = best_matching_FHRSID = np.nan
        else:
            idx_best_match = search_df['scores'].idxmax()
            score_best_match = search_df.loc[idx_best_match].scores
            best_matching_FHRSID = search_df.loc[idx_best_match].FHRSID
        print(f'\rMatched {i_counter}/{df.shape[0]}: {best_matching_FHRSID}, score: {score_best_match}', end='')
    
    return MATCHES

# %%
matches_dict = find_matches(df=df_yelp)
# Out:
# Matched 1534/1553: nan, score: nan

# %%
# creating match matrix
match_matrix = pd.DataFrame(matches_dict)
match_matrix.index.name = 'FHRSID'
match_matrix.columns.name = 'yelp_id'
match_matrix.head()

# combining reciprocal maximums scoring matches only
col_max = match_matrix.idxmax(axis=1)
row_max = match_matrix.idxmax(axis=0)
col_max.name = 'yelp_id'
row_max.name = 'FHRSID'
d1 = col_max.reset_index()
d2 = row_max.reset_index()
df_matches = pd.merge(d1, d2, on=['FHRSID', 'yelp_id'], how='inner')

# %%
# adding FHRSID to Yelp dataset via inner join
df_agumented = pd.merge(left=df_yelp_full, right=df_matches, left_on='id', right_on='yelp_id', how='inner')

# %%
df_agumented[['name', 'rating', 'review_count', 'price', 'latitude', 'longitude', 'zip_code', 'id', 'address1', 'FHRSID']]\
    .to_csv('yelp_matched.csv', index=0)
